# %%
# %load_ext autoreload
# %autoreload 2
#required packages
import os
import glob
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
from scipy import signal
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn import cluster
import pickle
from datetime import datetime
from tqdm import tqdm
#need to run as administrator, otherwise takes too long
# import umap
#my funcs
from ecog_functions import *

#inductive 
from sklearn.base import BaseEstimator, clone
from sklearn.cluster import AgglomerativeClustering
from sklearn.ensemble import RandomForestClassifier
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.utils.metaestimators import available_if
from sklearn.utils.validation import check_is_fitted

# %%
#two options - either fit new models, or train models on baseline

# %%
#global params
MODE = 'apply' #apply applies trained clusterer, train trains a new one. Trying to use one clusterer per rat
DATA_PATH = r"C:\Users\marty\Documents\DATA\water_soluble_cbn_sleep\*\timestamped\*.txt"     #r"G:\DATA\tween_cbn_sleep\*\timestamped\*.txt"
SAMPLE_RATE = 1000
OVERWRITE = False
DATA_SUFFIX = '_clustered_rolled_50cl_fullfixed.pkl'
MODEL_SUFFIX = '_final_50cl.pkl'
RELATIVE = True #whether to calculate relative power or absolute power
WARN_BY_CORR = False

# %%
#select DAYS and RATS
rats=['\\51\\','\\52\\','\\53\\','\\54\\','\\55\\',
      '\\41\\','\\42\\','\\43\\','\\44\\','\\45\\','\\46\\',
      '\\21\\','\\23\\','\\24\\','\\25\\','\\26\\',
      '\\31\\','\\32\\','\\33\\','\\34\\','\\35\\',
      '\\5\\','\\6\\','\\7\\','\\8\\','\\10\\',
      '\\11\\','\\12\\','\\13\\','\\14\\','\\16\\']
#read paths - here set where DATA should be read from
paths = glob.glob(DATA_PATH)
#for training
# days = ['20241903','20230604','20232905','20230811','20240801']

# %%
EXTRA_PATHS = r"G:\DATA\tween_cbn_sleep\*\timestamped\*.txt"
paths.extend(glob.glob(EXTRA_PATHS))

# %%
# #select specific days for specific rats - optional step, when specific days matter (ex. for apply mode)
days_rat51 = ['20241703','20241803','20241903','20242003','20242103','20242203','20242303','20242403','20242503','20242603','20242703','20242803','20242903','20243003','20240104','20240204','20240304','20240404','20240504','20240604']
days_rat52 = ['20241703','20241803','20241903','20242003','20242103','20242203','20242303','20242403','20242503','20242603','20242703','20242803','20242903','20243003','20240104','20240204','20240304','20240404','20240504','20240604']
days_rat53 = ['20241703','20241803','20241903','20242003','20242103','20242203','20242303','20242403','20242503','20242603','20242703','20242803','20242903','20243003','20240104','20240204','20240304','20240404','20240504','20240604']
days_rat54 = ['20241703','20241803','20241903','20242003','20242103','20242203','20242303','20242403','20242503','20242603','20242703','20242803','20242903','20243003','20240104','20240204','20240304','20240404','20240504','20240604']
days_rat55 = ['20241703','20241803','20241903','20242003','20242103','20242203','20242303','20242403','20242503','20242603','20242703','20242803','20242903','20243003','20240104','20240204','20240304','20240404','20240504','20240604']
days_rat41 = ['20242202','20242302','20242402','20242502','20242602','20242702','20242802','20242902','20240203','20240303','20240403','20240503', '20241103']
days_rat42 = ['20242202','20242302','20242402','20242502','20242602','20242702','20242802','20242902','20240103','20240203','20240303','20240403','20240503', '20241103','20241203','20241303','20241403','20241503']
days_rat43 = ['20242202','20242302','20242402','20242502','20242602','20242702','20242802','20242902','20240103','20240203','20240303','20240403','20240503', '20241103','20241203','20241303','20241403','20241503']
days_rat44 = ['20242202','20242302','20242402','20242502','20242602','20242702','20242802','20242902','20240103','20240203','20240303','20240403','20240503', '20241103','20241203','20241303','20241403','20241503']
days_rat45 = ['20242202','20242302','20242402','20242502','20242602','20242702','20242802','20242902','20240103','20240203','20240303','20240403','20240503', '20241303','20241403','20241503']
days_rat46 = ['20242202','20242302','20242402','20242502','20242602','20242702','20242802','20242902','20240103','20240203','20240303','20240403','20240503', '20241103','20241203','20241303','20241403','20241503']
days_rat21=['20230711','20230811','20230911','20231011','20231111','20231211','20231311','20231411','20231811','20231911','20232011', '20233011','20230112','20230212']
days_rat23=['20230711','20230811','20230911','20231011','20231111','20231211','20231311','20231411','20231511','20231611','20231711','20231811','20233011','20230112','20230212','20230312','20230412']
days_rat24=['20230711','20230811','20230911','20231011','20231111','20231211','20231311','20231411','20231511','20231611','20231711','20231811','20231911', '20230112','20230212','20230312','20230412']
days_rat25=['20230711','20230811','20230911','20231011','20231111','20231211','20231311','20231411','20231511','20231811','20231911']
days_rat26=['20230711','20230811','20230911','20231011','20231111','20231211','20231311','20231411','20231511','20231711','20231811','20231911', '20233011','20230112','20230212']
days_rat31=['20240801','20240901','20241001','20241101','20241201','20241301','20241401','20242001','20242101','20242201','20242301','20242401','20242501']
days_rat32=['20232912','20233012','20233112','20240101','20240201','20240301','20240401','20240501','20240601','20240801','20240901','20241001','20241101','20241201','20241301','20241401','20241501','20242001','20242101','20242201','20242301','20242401','20242501','20242601']
days_rat33=['20232912','20233012','20233112','20240101','20240201','20240301','20240401','20240501','20240601','20240801','20240901','20241001','20241101','20241201','20241301','20241401','20241501','20242001','20242101','20242201','20242301','20242401','20242501','20242601']
days_rat34=['20232912','20233012','20233112','20240101','20240201','20240301','20240401','20240501','20240601','20240801','20240901','20241001','20241101','20241201','20241301','20241401','20242001','20242101','20242201','20242301','20242401','20242501','20242601']
days_rat35=['20232912','20233012','20233112','20240101','20240201','20240301','20240401','20240501','20240601','20240801','20240901','20241001','20241101','20241201','20241301','20241401','20241501','20242001','20242101','20242201','20242301','20242401','20242501','20242601']
days_rat5=['20230504','20230604','20230704','20230804','20230904','20231004','20231104']
days_rat6=['20230504','20230604','20230704','20230804','20230904']
days_rat7=['20230504','20230604','20230704','20230804']
days_rat8=['20230504','20230604','20230704','20230804','20230904']
days_rat10=['20230504','20230604','20230704'] 
days_rat11=['20232705','20232805','20232905''20233005','20233105','20230106','20230206','20230306','20230406','20230506', '20232206', '20232306', '20232406', '20232506', '20232606']
days_rat12=['20232705','20232805','20232905''20233005','20233105','20230106','20230406','20230506','20230606','20230706','20230806', '20232206', '20232306']
days_rat13=['20232705','20232805','20232905''20233005','20233105','20230106','20230406','20230506','20230606','20230706','20230806','20230906','20231006', '20232206', '20232306', '20232406', '20232506', '20232606']
days_rat14=['20232705','20232805','20232905''20233005','20233105','20230106','20230206','20230306','20230406','20230506','20230606','20230706','20230806','20230906','20231006','20232206', '20232306', '20232406', '20232506', '20232606']
days_rat16=['20232705','20232805','20232905''20233005','20233105','20230106','20230206','20230306','20230406','20230506','20230606','20230706','20232306', '20232406', '20232506']
# #put to a list
days_allrats=[days_rat51, days_rat52, days_rat53, days_rat54, days_rat55, 
              days_rat41,days_rat42,days_rat43,days_rat44,days_rat45,days_rat46, 
              days_rat21,days_rat23,days_rat24,days_rat25,days_rat26,
              days_rat31,days_rat32,days_rat33,days_rat34,days_rat35,
              days_rat5,days_rat6,days_rat7,days_rat8,
              days_rat10,days_rat11,days_rat12,days_rat13,days_rat14,days_rat16]#

# %%
#selects each rat
sel_paths=[]
for rat in tqdm(range(0,len(rats))):
    #optional - selected days (comment single line below to change to same days for all rats)
    days=days_allrats[rat]
    
    for day in range(0,len(days)):
        print(f'{rats[rat]}, {days[day]} started')
        sel_paths = [p for p in paths if days[day] in p and rats[rat] in p]
        print(len(sel_paths))
        
        #savepath
        savepath = 'C:/Users/marty/Projects/sleep_new/res_temp/'
        savepath += str(rats[rat]).strip('\\') + '_'+str(days[day]) + DATA_SUFFIX
        #don't overwrite
        if os.path.isfile(savepath):
            if not OVERWRITE:
                print(f'{savepath} exists, skipping')
                continue
        
        #read data
        data=read_txt(sel_paths)
        if len(data)<1:
            continue
        #get data in mv
        data=convert_to_mv(data)
        #convert index
        data.index=pd.to_datetime(data['time'])
        print('data read done')
        
        #get corrs to warn by channel
        if WARN_BY_CORR:
            highcorrsum = np.sum(np.sum(data.drop('time', axis = 1).corr()>0.9))
            if highcorrsum > 4:
                print(f'warning: found {highcorrsum-4} highly correlated channels')
            else:
                print('all corrs < 0.9')
               
        #filtering
        filtered_data=pd.DataFrame()
        filtered_data['l_ecog']=filter_channel(data['l_ecog'], fstart=0.5, fstop=45, sr=SAMPLE_RATE, center=True, notch_50=False)
        filtered_data['r_ecog']=filter_channel(data['r_ecog'], fstart=0.5, fstop=45, sr=SAMPLE_RATE, center=True, notch_50=False)
        #LFP data not needed for sleep scoring
        #filtered_data['lfp']=filter_channel(data['lfp'], fstart=0.5, fstop=45, sr=1000, center=True, notch_50=True)
        filtered_data['emg']=filter_channel(data['emg'], fstart=5, fstop=100, sr=SAMPLE_RATE, center=True, notch_50=True)
        filtered_data.index=data.index
        print('filtering done')
        
        #get PCA to merge ecog channels
        sel_chs=['l_ecog','r_ecog']
        pca=PCA(n_components=2)
        #select first component
        to_features=pca.fit_transform(filtered_data[sel_chs])[:,0]
        print(pca.explained_variance_ratio_)
        
        #get spectral components
        BANDWIDTHS = {
            'delta': (0.5, 4),
            'theta': (4, 8),
            'alpha': (8, 13),
            'beta': (13, 30),
            'gamma': (30, 45)
        }
        #create filters
        bandwidth_filters = {
            name: signal.butter(N=20, Wn=frange, btype='bp', output='sos',  fs=SAMPLE_RATE)
            for name, frange in BANDWIDTHS.items()
        }
        #create output df
        freq_comps=pd.DataFrame()
        freq_comps.index=filtered_data.index
        #split to freq comps
        for i, (b, filter) in enumerate(bandwidth_filters.items()):
            freq_comps[str(b)] = signal.sosfiltfilt(filter, to_features)
        #add emg
        freq_comps['emg']=filtered_data['emg']
                
        #convert to power
        pows = []
        index = []
        for col in freq_comps.columns:
            pow,ind,var = signal_to_power(freq_comps[col])
            pows.append(pow)
            index.append(ind)
        freq_powers = pd.DataFrame(pows).T
        freq_powers.columns = freq_comps.columns
        freq_powers.index = index[0]
        
        #get power ratios
        #convert to relative power - take each row and divide it by the sum of that row
        #ignore EMG since it's not cortical and has different values - is basically always max if included
        if RELATIVE:
            for ind in freq_powers.index:
                freq_powers.loc[ind,freq_powers.columns[:-1]]=freq_powers.loc[ind,freq_powers.columns[:-1]]/freq_powers.loc[ind,freq_powers.columns[:-1]].sum()
        
        #also standardize cols
        scaler = StandardScaler()
        freq_powers[freq_powers.columns]=scaler.fit_transform(freq_powers[freq_powers.columns])
        
        #apply a rolling median filter 60 points
        freq_powers = freq_powers.rolling(60).median()#.fillna(method='bfill',inplace=True)
        freq_powers = freq_powers.fillna(method='bfill')
        
        #save/load path
        ind_learner_path = './models/ind_'+str(rats[rat]).strip('\\')+MODEL_SUFFIX
        
        #code for applying a trained clusterer
        if MODE == 'apply':
            #check if the file exists
            if not os.path.isfile(ind_learner_path):
                print(f"{ind_learner_path} doesn't exist, training instead")
                MODE = 'train'
                #if file doesn;t exist, train instead
            #if clusterer exists, do clustering
            else:
                inductive_learner = pickle.load(open(ind_learner_path,'rb'))
                X = freq_powers.values
                freq_powers['cluster']=inductive_learner.predict(X)
                freq_powers['cluster']=freq_powers['cluster'].astype('category')
            
        #code for training a new clusterer
        if MODE == 'train':
            #try clustering 
            X = freq_powers.values
            #select subset to save memory
            idx = np.random.randint(len(X), size=50000)
            subset=X[idx]

            clusterer = AgglomerativeClustering(n_clusters=50, linkage='ward')
            cluster_labels = clusterer.fit_predict(subset)

            # inductive learning model to replicate agglomerative clustering on new data - way more efficient
            classifier = RandomForestClassifier(random_state=42)
            inductive_learner = InductiveClusterer(clusterer, classifier).fit(X)

            #predictions from inductive clusterer
            freq_powers['cluster']=inductive_learner.predict(X)
            freq_powers['cluster']=freq_powers['cluster'].astype('category')
            
            #save inductive learner
            pickle.dump(inductive_learner, open(ind_learner_path, 'wb'))
            
            #sort clusters
            
            grouped=freq_powers.groupby('cluster').median()
            grouped['cluster']=freq_powers.groupby('cluster').median().index
            grouped['sleep']='unknown'
            #saving results
            pickle.dump(grouped, open('./res_temp/grouped_cls_'+str(rats[rat]).strip('\\')+MODEL_SUFFIX, 'wb'))
        
        #else for troubleshooting
        #else:
            #print('weird error, MODE not recognized')
            #break
        
        pickle.dump(freq_powers,open(savepath, 'wb'))

        print(f'{rats[rat]}, {days[day]} done')
print('all done')
# Out:
#  45%|████▌     | 14/31 [00:00<00:00, 130.71it/s]
# \51\, 20241703 started
# 11
# C:/Users/marty/Projects/sleep_new/res_temp/51_20241703_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20241803 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/51_20241803_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20241903 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/51_20241903_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20242003 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/51_20242003_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20242103 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/51_20242103_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20242203 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/51_20242203_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20242303 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/51_20242303_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20242403 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/51_20242403_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20242503 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/51_20242503_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20242603 started
# 21
# C:/Users/marty/Projects/sleep_new/res_temp/51_20242603_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20242703 started
# 15
# C:/Users/marty/Projects/sleep_new/res_temp/51_20242703_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20242803 started
# 22
# C:/Users/marty/Projects/sleep_new/res_temp/51_20242803_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20242903 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/51_20242903_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20243003 started
# 10
# C:/Users/marty/Projects/sleep_new/res_temp/51_20243003_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20240104 started
# 17
# C:/Users/marty/Projects/sleep_new/res_temp/51_20240104_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20240204 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/51_20240204_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20240304 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/51_20240304_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20240404 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/51_20240404_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20240504 started
# 9
# C:/Users/marty/Projects/sleep_new/res_temp/51_20240504_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \51\, 20240604 started
# 0
# \52\, 20241703 started
# 11
# C:/Users/marty/Projects/sleep_new/res_temp/52_20241703_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \52\, 20241803 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/52_20241803_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \52\, 20241903 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/52_20241903_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \52\, 20242003 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/52_20242003_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \52\, 20242103 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/52_20242103_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \52\, 20242203 started
# 13
# C:/Users/marty/Projects/sleep_new/res_temp/52_20242203_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \52\, 20242303 started
# 13
# C:/Users/marty/Projects/sleep_new/res_temp/52_20242303_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \52\, 20242403 started
# 22
# C:/Users/marty/Projects/sleep_new/res_temp/52_20242403_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \52\, 20242503 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/52_20242503_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \52\, 20242603 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/52_20242603_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \52\, 20242703 started
# 10
# C:/Users/marty/Projects/sleep_new/res_temp/52_20242703_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \52\, 20242803 started
# 0
# \52\, 20242903 started
# 0
# \52\, 20243003 started
# 0
# \52\, 20240104 started
# 1
# C:/Users/marty/Projects/sleep_new/res_temp/52_20240104_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \52\, 20240204 started
# 10
# C:/Users/marty/Projects/sleep_new/res_temp/52_20240204_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \52\, 20240304 started
# 0
# \52\, 20240404 started
# 0
# \52\, 20240504 started
# 0
# \52\, 20240604 started
# 0
# \53\, 20241703 started
# 0
# \53\, 20241803 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/53_20241803_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20241903 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/53_20241903_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20242003 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/53_20242003_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20242103 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/53_20242103_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20242203 started
# 22
# C:/Users/marty/Projects/sleep_new/res_temp/53_20242203_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20242303 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/53_20242303_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20242403 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/53_20242403_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20242503 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/53_20242503_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20242603 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/53_20242603_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20242703 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/53_20242703_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20242803 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/53_20242803_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20242903 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/53_20242903_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20243003 started
# 10
# C:/Users/marty/Projects/sleep_new/res_temp/53_20243003_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20240104 started
# 17
# C:/Users/marty/Projects/sleep_new/res_temp/53_20240104_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20240204 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/53_20240204_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20240304 started
# 20
# C:/Users/marty/Projects/sleep_new/res_temp/53_20240304_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20240404 started
# 15
# C:/Users/marty/Projects/sleep_new/res_temp/53_20240404_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20240504 started
# 22
# C:/Users/marty/Projects/sleep_new/res_temp/53_20240504_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \53\, 20240604 started
# 0
# \54\, 20241703 started
# 10
# C:/Users/marty/Projects/sleep_new/res_temp/54_20241703_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20241803 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/54_20241803_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20241903 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/54_20241903_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20242003 started
# 17
# C:/Users/marty/Projects/sleep_new/res_temp/54_20242003_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20242103 started
# 13
# C:/Users/marty/Projects/sleep_new/res_temp/54_20242103_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20242203 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/54_20242203_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20242303 started
# 22
# C:/Users/marty/Projects/sleep_new/res_temp/54_20242303_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20242403 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/54_20242403_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20242503 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/54_20242503_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20242603 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/54_20242603_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20242703 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/54_20242703_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20242803 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/54_20242803_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20242903 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/54_20242903_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20243003 started
# 3
# C:/Users/marty/Projects/sleep_new/res_temp/54_20243003_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20240104 started
# 15
# C:/Users/marty/Projects/sleep_new/res_temp/54_20240104_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20240204 started
# 9
# C:/Users/marty/Projects/sleep_new/res_temp/54_20240204_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20240304 started
# 15
# C:/Users/marty/Projects/sleep_new/res_temp/54_20240304_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20240404 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/54_20240404_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \54\, 20240504 started
# 0
# \54\, 20240604 started
# 0
# \55\, 20241703 started
# 11
# C:/Users/marty/Projects/sleep_new/res_temp/55_20241703_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \55\, 20241803 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/55_20241803_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \55\, 20241903 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/55_20241903_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \55\, 20242003 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/55_20242003_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \55\, 20242103 started
# 31
# C:/Users/marty/Projects/sleep_new/res_temp/55_20242103_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \55\, 20242203 started
# 22
# C:/Users/marty/Projects/sleep_new/res_temp/55_20242203_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \55\, 20242303 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/55_20242303_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \55\, 20242403 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/55_20242403_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \55\, 20242503 started
# 10
# C:/Users/marty/Projects/sleep_new/res_temp/55_20242503_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \55\, 20242603 started
# 13
# C:/Users/marty/Projects/sleep_new/res_temp/55_20242603_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \55\, 20242703 started
# 10
# C:/Users/marty/Projects/sleep_new/res_temp/55_20242703_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \55\, 20242803 started
# 0
# \55\, 20242903 started
# 0
# \55\, 20243003 started
# 0
# \55\, 20240104 started
# 15
# C:/Users/marty/Projects/sleep_new/res_temp/55_20240104_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \55\, 20240204 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/55_20240204_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \55\, 20240304 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/55_20240304_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \55\, 20240404 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/55_20240404_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \55\, 20240504 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/55_20240504_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \55\, 20240604 started
# 10
# C:/Users/marty/Projects/sleep_new/res_temp/55_20240604_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \41\, 20242202 started
# 8
# C:/Users/marty/Projects/sleep_new/res_temp/41_20242202_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \41\, 20242302 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/41_20242302_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \41\, 20242402 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/41_20242402_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \41\, 20242502 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/41_20242502_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \41\, 20242602 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/41_20242602_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \41\, 20242702 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/41_20242702_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \41\, 20242802 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/41_20242802_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \41\, 20242902 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/41_20242902_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \41\, 20240203 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/41_20240203_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \41\, 20240303 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/41_20240303_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \41\, 20240403 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/41_20240403_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \41\, 20240503 started
# 9
# C:/Users/marty/Projects/sleep_new/res_temp/41_20240503_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \41\, 20241103 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/41_20241103_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20242202 started
# 7
# C:/Users/marty/Projects/sleep_new/res_temp/42_20242202_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20242302 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/42_20242302_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20242402 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/42_20242402_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20242502 started
# 22
# C:/Users/marty/Projects/sleep_new/res_temp/42_20242502_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20242602 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/42_20242602_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20242702 started
# 9
# C:/Users/marty/Projects/sleep_new/res_temp/42_20242702_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20242802 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/42_20242802_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20242902 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/42_20242902_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20240103 started
# 17
# C:/Users/marty/Projects/sleep_new/res_temp/42_20240103_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20240203 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/42_20240203_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20240303 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/42_20240303_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20240403 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/42_20240403_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20240503 started
# 9
# C:/Users/marty/Projects/sleep_new/res_temp/42_20240503_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20241103 started
# 22
# C:/Users/marty/Projects/sleep_new/res_temp/42_20241103_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20241203 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/42_20241203_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20241303 started
# 9
# C:/Users/marty/Projects/sleep_new/res_temp/42_20241303_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20241403 started
# 13
# C:/Users/marty/Projects/sleep_new/res_temp/42_20241403_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \42\, 20241503 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/42_20241503_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \43\, 20242202 started
# 6
# C:/Users/marty/Projects/sleep_new/res_temp/43_20242202_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \43\, 20242302 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/43_20242302_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \43\, 20242402 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/43_20242402_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \43\, 20242502 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/43_20242502_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \43\, 20242602 started
# 22
# C:/Users/marty/Projects/sleep_new/res_temp/43_20242602_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \43\, 20242702 started
# 11
# C:/Users/marty/Projects/sleep_new/res_temp/43_20242702_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \43\, 20242802 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/43_20242802_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \43\, 20242902 started
# 10
# C:/Users/marty/Projects/sleep_new/res_temp/43_20242902_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \43\, 20240103 started
# 1
# C:/Users/marty/Projects/sleep_new/res_temp/43_20240103_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \43\, 20240203 started
# 1
# C:/Users/marty/Projects/sleep_new/res_temp/43_20240203_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \43\, 20240303 started
# 0
# \43\, 20240403 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/43_20240403_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \43\, 20240503 started
# 3
# C:/Users/marty/Projects/sleep_new/res_temp/43_20240503_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \43\, 20241103 started
# 9
# C:/Users/marty/Projects/sleep_new/res_temp/43_20241103_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \43\, 20241203 started
# 3
# C:/Users/marty/Projects/sleep_new/res_temp/43_20241203_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \43\, 20241303 started
# 0
# \43\, 20241403 started
# 5
# C:/Users/marty/Projects/sleep_new/res_temp/43_20241403_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \43\, 20241503 started
# 6
# C:/Users/marty/Projects/sleep_new/res_temp/43_20241503_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \44\, 20242202 started
# 0
# \44\, 20242302 started
# 12
# C:/Users/marty/Projects/sleep_new/res_temp/44_20242302_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \44\, 20242402 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/44_20242402_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \44\, 20242502 started
# 20
# C:/Users/marty/Projects/sleep_new/res_temp/44_20242502_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \44\, 20242602 started
# 13
# C:/Users/marty/Projects/sleep_new/res_temp/44_20242602_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \44\, 20242702 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/44_20242702_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \44\, 20242802 started
# 11
# C:/Users/marty/Projects/sleep_new/res_temp/44_20242802_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \44\, 20242902 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/44_20242902_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \44\, 20240103 started
# 3
# C:/Users/marty/Projects/sleep_new/res_temp/44_20240103_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \44\, 20240203 started
# 12
# C:/Users/marty/Projects/sleep_new/res_temp/44_20240203_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \44\, 20240303 started
# 10
# C:/Users/marty/Projects/sleep_new/res_temp/44_20240303_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \44\, 20240403 started
# 0
# \44\, 20240503 started
# 0
# \44\, 20241103 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/44_20241103_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \44\, 20241203 started
# 16
# C:/Users/marty/Projects/sleep_new/res_temp/44_20241203_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \44\, 20241303 started
# 11
# C:/Users/marty/Projects/sleep_new/res_temp/44_20241303_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \44\, 20241403 started
# 11
# C:/Users/marty/Projects/sleep_new/res_temp/44_20241403_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \44\, 20241503 started
# 13
# C:/Users/marty/Projects/sleep_new/res_temp/44_20241503_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \45\, 20242202 started
# 8
# C:/Users/marty/Projects/sleep_new/res_temp/45_20242202_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \45\, 20242302 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/45_20242302_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \45\, 20242402 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/45_20242402_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \45\, 20242502 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/45_20242502_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \45\, 20242602 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/45_20242602_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \45\, 20242702 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/45_20242702_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \45\, 20242802 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/45_20242802_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \45\, 20242902 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/45_20242902_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \45\, 20240103 started
# 17
# C:/Users/marty/Projects/sleep_new/res_temp/45_20240103_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \45\, 20240203 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/45_20240203_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \45\, 20240303 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/45_20240303_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \45\, 20240403 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/45_20240403_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \45\, 20240503 started
# 9
# C:/Users/marty/Projects/sleep_new/res_temp/45_20240503_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \45\, 20241303 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/45_20241303_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \45\, 20241403 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/45_20241403_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \45\, 20241503 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/45_20241503_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20242202 started
# 5
# C:/Users/marty/Projects/sleep_new/res_temp/46_20242202_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20242302 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/46_20242302_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20242402 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/46_20242402_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20242502 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/46_20242502_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20242602 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/46_20242602_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20242702 started
# 22
# C:/Users/marty/Projects/sleep_new/res_temp/46_20242702_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20242802 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/46_20242802_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20242902 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/46_20242902_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20240103 started
# 16
# C:/Users/marty/Projects/sleep_new/res_temp/46_20240103_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20240203 started
# 18
# C:/Users/marty/Projects/sleep_new/res_temp/46_20240203_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20240303 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/46_20240303_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20240403 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/46_20240403_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20240503 started
# 9
# C:/Users/marty/Projects/sleep_new/res_temp/46_20240503_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20241103 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/46_20241103_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20241203 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/46_20241203_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20241303 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/46_20241303_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20241403 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/46_20241403_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \46\, 20241503 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/46_20241503_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \21\, 20230711 started
# 7
# C:/Users/marty/Projects/sleep_new/res_temp/21_20230711_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \21\, 20230811 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/21_20230811_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \21\, 20230911 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/21_20230911_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \21\, 20231011 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/21_20231011_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \21\, 20231111 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/21_20231111_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \21\, 20231211 started
# 21
# C:/Users/marty/Projects/sleep_new/res_temp/21_20231211_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \21\, 20231311 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/21_20231311_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \21\, 20231411 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/21_20231411_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \21\, 20231811 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/21_20231811_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \21\, 20231911 started
# 22
# C:/Users/marty/Projects/sleep_new/res_temp/21_20231911_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \21\, 20232011 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/21_20232011_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \21\, 20233011 started
# 21
# C:/Users/marty/Projects/sleep_new/res_temp/21_20233011_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \21\, 20230112 started
# 16
# C:/Users/marty/Projects/sleep_new/res_temp/21_20230112_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \21\, 20230212 started
# 3
# C:/Users/marty/Projects/sleep_new/res_temp/21_20230212_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \23\, 20230711 started
# 7
# C:/Users/marty/Projects/sleep_new/res_temp/23_20230711_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \23\, 20230811 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/23_20230811_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \23\, 20230911 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/23_20230911_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \23\, 20231011 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/23_20231011_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \23\, 20231111 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/23_20231111_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \23\, 20231211 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/23_20231211_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \23\, 20231311 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/23_20231311_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \23\, 20231411 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/23_20231411_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \23\, 20231511 started
# 18
# C:/Users/marty/Projects/sleep_new/res_temp/23_20231511_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \23\, 20231611 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/23_20231611_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \23\, 20231711 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/23_20231711_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \23\, 20231811 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/23_20231811_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \23\, 20233011 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/23_20233011_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \23\, 20230112 started
# 16
# C:/Users/marty/Projects/sleep_new/res_temp/23_20230112_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \23\, 20230212 started
# 18
# C:/Users/marty/Projects/sleep_new/res_temp/23_20230212_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \23\, 20230312 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/23_20230312_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \23\, 20230412 started
# 19
# C:/Users/marty/Projects/sleep_new/res_temp/23_20230412_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \24\, 20230711 started
# 6
# C:/Users/marty/Projects/sleep_new/res_temp/24_20230711_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \24\, 20230811 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/24_20230811_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \24\, 20230911 started
# 22
# C:/Users/marty/Projects/sleep_new/res_temp/24_20230911_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \24\, 20231011 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/24_20231011_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \24\, 20231111 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/24_20231111_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \24\, 20231211 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/24_20231211_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \24\, 20231311 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/24_20231311_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \24\, 20231411 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/24_20231411_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \24\, 20231511 started
# 20
# C:/Users/marty/Projects/sleep_new/res_temp/24_20231511_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \24\, 20231611 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/24_20231611_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \24\, 20231711 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/24_20231711_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \24\, 20231811 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/24_20231811_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \24\, 20231911 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/24_20231911_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \24\, 20230112 started
# 5
# C:/Users/marty/Projects/sleep_new/res_temp/24_20230112_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \24\, 20230212 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/24_20230212_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \24\, 20230312 started
# 20
# C:/Users/marty/Projects/sleep_new/res_temp/24_20230312_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \24\, 20230412 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/24_20230412_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \25\, 20230711 started
# 6
# C:/Users/marty/Projects/sleep_new/res_temp/25_20230711_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \25\, 20230811 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/25_20230811_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \25\, 20230911 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/25_20230911_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \25\, 20231011 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/25_20231011_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \25\, 20231111 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/25_20231111_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \25\, 20231211 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/25_20231211_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \25\, 20231311 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/25_20231311_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \25\, 20231411 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/25_20231411_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \25\, 20231511 started
# 20
# C:/Users/marty/Projects/sleep_new/res_temp/25_20231511_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \25\, 20231811 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/25_20231811_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \25\, 20231911 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/25_20231911_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \26\, 20230711 started
# 6
# C:/Users/marty/Projects/sleep_new/res_temp/26_20230711_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \26\, 20230811 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/26_20230811_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \26\, 20230911 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/26_20230911_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \26\, 20231011 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/26_20231011_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \26\, 20231111 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/26_20231111_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \26\, 20231211 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/26_20231211_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \26\, 20231311 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/26_20231311_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \26\, 20231411 started
# 10
# C:/Users/marty/Projects/sleep_new/res_temp/26_20231411_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \26\, 20231511 started
# 10
# C:/Users/marty/Projects/sleep_new/res_temp/26_20231511_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \26\, 20231711 started
# 22
# C:/Users/marty/Projects/sleep_new/res_temp/26_20231711_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \26\, 20231811 started
# 21
# C:/Users/marty/Projects/sleep_new/res_temp/26_20231811_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \26\, 20231911 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/26_20231911_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \26\, 20233011 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/26_20233011_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \26\, 20230112 started
# 16
# C:/Users/marty/Projects/sleep_new/res_temp/26_20230112_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \26\, 20230212 started
# 3
# C:/Users/marty/Projects/sleep_new/res_temp/26_20230212_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \31\, 20240801 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/31_20240801_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \31\, 20240901 started
# 16
# C:/Users/marty/Projects/sleep_new/res_temp/31_20240901_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \31\, 20241001 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/31_20241001_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \31\, 20241101 started
# 25
# C:/Users/marty/Projects/sleep_new/res_temp/31_20241101_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \31\, 20241201 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/31_20241201_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \31\, 20241301 started
# 16
# C:/Users/marty/Projects/sleep_new/res_temp/31_20241301_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \31\, 20241401 started
# 5
# C:/Users/marty/Projects/sleep_new/res_temp/31_20241401_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \31\, 20242001 started
# 20
# C:/Users/marty/Projects/sleep_new/res_temp/31_20242001_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \31\, 20242101 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/31_20242101_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \31\, 20242201 started
# 22
# C:/Users/marty/Projects/sleep_new/res_temp/31_20242201_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \31\, 20242301 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/31_20242301_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \31\, 20242401 started
# 15
# C:/Users/marty/Projects/sleep_new/res_temp/31_20242401_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \31\, 20242501 started
# 1
# C:/Users/marty/Projects/sleep_new/res_temp/31_20242501_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20232912 started
# 4
# C:/Users/marty/Projects/sleep_new/res_temp/32_20232912_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20233012 started
# 13
# C:/Users/marty/Projects/sleep_new/res_temp/32_20233012_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20233112 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/32_20233112_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20240101 started
# 12
# C:/Users/marty/Projects/sleep_new/res_temp/32_20240101_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20240201 started
# 15
# C:/Users/marty/Projects/sleep_new/res_temp/32_20240201_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20240301 started
# 7
# C:/Users/marty/Projects/sleep_new/res_temp/32_20240301_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20240401 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/32_20240401_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20240501 started
# 11
# C:/Users/marty/Projects/sleep_new/res_temp/32_20240501_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20240601 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/32_20240601_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20240801 started
# 13
# C:/Users/marty/Projects/sleep_new/res_temp/32_20240801_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20240901 started
# 10
# C:/Users/marty/Projects/sleep_new/res_temp/32_20240901_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20241001 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/32_20241001_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20241101 started
# 11
# C:/Users/marty/Projects/sleep_new/res_temp/32_20241101_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20241201 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/32_20241201_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20241301 started
# 10
# C:/Users/marty/Projects/sleep_new/res_temp/32_20241301_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20241401 started
# 13
# C:/Users/marty/Projects/sleep_new/res_temp/32_20241401_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20241501 started
# 13
# C:/Users/marty/Projects/sleep_new/res_temp/32_20241501_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20242001 started
# 12
# C:/Users/marty/Projects/sleep_new/res_temp/32_20242001_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20242101 started
# 13
# C:/Users/marty/Projects/sleep_new/res_temp/32_20242101_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20242201 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/32_20242201_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20242301 started
# 15
# C:/Users/marty/Projects/sleep_new/res_temp/32_20242301_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20242401 started
# 10
# C:/Users/marty/Projects/sleep_new/res_temp/32_20242401_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20242501 started
# 14
# C:/Users/marty/Projects/sleep_new/res_temp/32_20242501_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \32\, 20242601 started
# 2
# C:/Users/marty/Projects/sleep_new/res_temp/32_20242601_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \33\, 20232912 started
# 9
# C:/Users/marty/Projects/sleep_new/res_temp/33_20232912_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \33\, 20233012 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/33_20233012_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \33\, 20233112 started
# 23
# C:/Users/marty/Projects/sleep_new/res_temp/33_20233112_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \33\, 20240101 started
# 15
# C:/Users/marty/Projects/sleep_new/res_temp/33_20240101_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \33\, 20240201 started
# 26
# C:/Users/marty/Projects/sleep_new/res_temp/33_20240201_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \33\, 20240301 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/33_20240301_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \33\, 20240401 started
# 20
# C:/Users/marty/Projects/sleep_new/res_temp/33_20240401_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \33\, 20240501 started
# 24
# C:/Users/marty/Projects/sleep_new/res_temp/33_20240501_clustered_rolled_50cl_fullfixed.pkl exists, skipping
# \33\, 20240601 started
# 25
# G:\DATA\tween_cbn_sleep\33\timestamped\202406010047.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406010147.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406010247.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406010347.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406010447.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406010547.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406010647.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406010747.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406010847.txt
#  45%|████▌     | 14/31 [00:20<00:00, 130.71it/s]
# G:\DATA\tween_cbn_sleep\33\timestamped\202406010947.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406010954.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406011058.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406011158.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406011258.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406011358.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406011458.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406011558.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406011658.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406011758.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406011858.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406011958.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406012058.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406012157.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406012257.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202406012357.txt
# data read done
# filtering done
# [0.90968224 0.09031776]
# \33\, 20240601 done
# \33\, 20240801 started
# 24
# G:\DATA\tween_cbn_sleep\33\timestamped\202408010057.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408010157.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408010257.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408010357.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408010457.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408010557.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408010656.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408010756.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408010856.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408010947.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408011048.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408011148.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408011248.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408011348.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408011448.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408011548.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408011647.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408011747.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408011847.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408011947.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408012047.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408012147.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408012247.txt
# G:\DATA\tween_cbn_sleep\33\timestamped\202408012347.txt
# data read done
# filtering done
# [0.9307323 0.0692677]
#  58%|█████▊    | 18/31 [16:06<11:37, 53.67s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 82
#      80 index = []
#      81 for col in freq_comps.columns:
# ---> 82     pow,ind,var = signal_to_power(freq_comps[col])
#      83     pows.append(pow)
#      84     index.append(ind)
#
# File c:\Users\marty\Projects\sleep_new\ecog_functions.py:132, in signal_to_power(signal, window, rolling)
#     130         power=np.append(power,power_subset)
#     131         indices=np.append(indices, signal_subset.index[0])
# --> 132         variances=np.append(variances, np.var(signal_subset))
#     134 return power, indices, variances
#
# File <__array_function__ internals>:180, in append(*args, **kwargs)
#
# File c:\ProgramData\Anaconda3\envs\basicdata\Lib\site-packages\numpy\lib\function_base.py:5444, in append(arr, values, axis)
#    5442     values = ravel(values)
#    5443     axis = arr.ndim-1
# -> 5444 return concatenate((arr, values), axis=axis)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:
